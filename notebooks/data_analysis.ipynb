# %% [markdown]
# # Indian House Price Analysis
#
# Data analysis and visualization for the Indian housing dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('../data/indian_housing_data.csv')
print(f"Dataset shape: {df.shape}")
df.head()
